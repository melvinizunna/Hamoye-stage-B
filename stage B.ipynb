# %% [markdown]
# Izunna Eliogu
# ID: 146ea351c801f000

# %%
import pandas as pd
import numpy as  np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

data=pd.read_csv('energydata_complete.csv')
data.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
data.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
#dropped the lights & date column
data=data.drop(columns=['date','lights'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\ASPIRE~1\AppData\Local\Temp/ipykernel_11008/3037055887.py in <module>
# ----> 1 data=data.drop(columns=['date','lights'])
#       2
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
data.isnull().sum()
# Out:
# Appliances     0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
data.shape
# Out:
# (19735, 27)

# %%
#question 12
x=np.array(normalized_df['T2'])
y=np.array(normalized_df['T6'])

#train_test_aplit

x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.3, random_state=4)
x_train=x_train.reshape(-1,1)
y_train=y_train.reshape(-1,1)
x_test=x_test.reshape(-1,1)

reg=LinearRegression()
reg.fit(x_train,y_train)
y_preds= reg.predict(x_test)

# %%
# r2_score
r=r2_score(y_test,y_preds)
r2
print('the r2 score is 0.65')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\ASPIRE~1\AppData\Local\Temp/ipykernel_11008/3475848879.py in <module>
#       1 # r2_score
# ----> 2 r=r2_score(y_test,y_preds)
#       3 r2
#       4 print('the r2 score is 0.65')
#
# TypeError: 'numpy.float64' object is not callable

# %%
#normalize the data

scaler=MinMaxScaler()

normalized_df=pd.DataFrame(scaler.fit_transform(data),columns=data.columns)
normalized_df
# Out:
#        Appliances        T1      RH_1        T2      RH_2        T3      RH_3  \
# 0        0.046729  0.327350  0.566187  0.225345  0.684038  0.215188  0.746066
# 1        0.046729  0.327350  0.541326  0.225345  0.682140  0.215188  0.748871
# 2        0.037383  0.327350  0.530502  0.225345  0.679445  0.215188  0.755569
# 3        0.037383  0.327350  0.524080  0.225345  0.678414  0.215188  0.758685
# 4        0.046729  0.327350  0.531419  0.225345  0.676727  0.215188  0.758685
# ...           ...       ...       ...       ...       ...       ...       ...
# 19730    0.084112  0.926786  0.537657  0.711655  0.606309  0.830841  0.579374
# 19731    0.074766  0.919747  0.536006  0.701769  0.607836  0.825302  0.582178
# 19732    0.242991  0.919747  0.538666  0.692651  0.627198  0.818378  0.603988
# 19733    0.383178  0.919747  0.549491  0.677054  0.634717  0.805085  0.585294
# 19734    0.392523  0.919747  0.538758  0.666171  0.632902  0.799546  0.579062
#
# ...

# %%
from sklearn.model_selection import train_test_split
x=normalized_df.drop(columns='Appliances')


y=normalized_df['Appliances']
y
# Out:
# 0        0.046729
# 1        0.046729
# 2        0.037383
# 3        0.037383
# 4        0.046729
#            ...
# 19730    0.084112
# 19731    0.074766
# 19732    0.242991
# 19733    0.383178
# 19734    0.392523
# Name: Appliances, Length: 19735, dtype: float64

# %%
reg=LinearRegression()
reg.fit(x_train,y_train)
y_pred= reg.predict(x_test)
# Out:
# array([0.0510702 , 0.1433121 , 0.07740383, ..., 0.11205469, 0.10467206,
#        0.12371611])

# %%
#question 13
mae=mean_absolute_error(y_test,y_pred)
mae
round(mae,2)
print('the MAE is 0.05 ')
# Out:
# the MAE is 0.05

# %%
reg.score(x_test,y_test)
# Out:
# 0.138206463698751

# %%
# Out:
# 0.138206463698751

# %%
#question 14
rss=np.sum(np.square(y_test-y_pred))
rss=round(rss,3)
rss
print(f'the rss is {rss}')
# Out:
# the rss is 45.839

# %%
#question 15
rmse=np.sqrt(mean_squared_error(y_test,y_pred))
rmse
round(rmse,2)
print('the rmse is 0.09')
# Out:
# 0.09

# %%
ridge_reg=Ridge(alpha=0.4)
ridge_reg.fit(x_train,y_train)
ridge=ridge_reg.predict(x_test)
ridge
# Out:
# array([0.05059935, 0.1424762 , 0.07651815, ..., 0.1111071 , 0.10449254,
#        0.12418605])

# %%
#number 16
from sklearn.metrics import r2_score
r2_score=r2_score(y_test,y_pred)
r2_score
round(r2_score,2)
print('the coefficient of determination is 0.14')
# Out:
# the coefficient of determination is 0.14

# %%
#question 17

def get_weights_df(model, feat, col_name):
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['Features', col_name]
    weights_df[col_name].round(4)
    return weights_df

linear_model_weights=get_weights_df(reg,x_train,'Linear_model_weight')
ridge_weights_df=get_weights_df(ridge_reg,x_train,'Ridge_weight')
lasso_weights_df=get_weights_df(lasso_reg,x_train,'Lasso_weight')
final_weights=pd.merge(linear_model_weights,ridge_weights_df, on='Features')
final_weights=pd.merge(final_weights,lasso_weights_df,on='Features')
final_weights
# Out:
#        Features  Linear_model_weight  Ridge_weight  Lasso_weight
# 0          RH_2            -0.476556     -0.429640     -0.000000
# 1         T_out            -0.281673     -0.231085      0.000000
# 2            T2            -0.270552     -0.234200      0.001136
# 3            T9            -0.202710     -0.202106     -0.000000
# 4          RH_8            -0.167031     -0.165750     -0.000000
# 5        RH_out            -0.048354     -0.030560     -0.054831
# 6          RH_7            -0.044144     -0.045558     -0.000000
# 7          RH_9            -0.032531     -0.034146     -0.000000
# 8            T5            -0.013567     -0.017323     -0.000000
# 9           rv2            -0.000877     -0.000883     -0.000000
# 10          rv1            -0.000877     -0.000883     -0.000000
# 11           T1             0.002613     -0.013105      0.000000
# 12  Press_mm_hg             0.004725      0.004466     -0.000000
# ...

# %%
#question 17
print('the highest & lowest weights in the lunear_model features are RH_2, RH_1')
# Out:
# the highest & lowest weights in the lunear_model features are RH_2, RH_1

# %%
#question 18

from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=0.4)
ridge_reg.fit(x_train, y_train)

pred_ridge = ridge_reg.predict(x_test)
rmse1 = np.sqrt(mean_squared_error(y_test, pred_ridge))
round(rmse1, 3)

print('No there was no difference in value')
# Out:
# No there was no difference in value

# %%
#question 19

lasso_reg = Lasso(alpha = 0.001)
lasso_reg.fit(x_train, y_train)
lasso=lasso_reg.predict(x_test)
lasso

pred = lasso_reg.predict(x_test)

lasso_weights_df = get_weights_df(lasso_reg, x_train, 'Lasso_weight')
lasso_weights_df

print('there are 4 non_zero values')
# Out:
# there are 4 non_zero values

# %%
#no 20
rmse2 = np.sqrt(mean_squared_error(y_test, pred))
round(rmse2, 3)
# Out:
# 0.094
